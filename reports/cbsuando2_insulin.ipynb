# %% [markdown]
# # mdx2 profiling summary

# %%
import os, platform, psutil

mem_bytes = psutil.virtual_memory().total
ncpu = os.cpu_count()
chip = platform.processor()  # or platform.machine()

print("Physical memory (GiB):", mem_bytes / 1024**3)
print("Number of CPU cores:", ncpu)
print("CPU:", chip)
# Out:
# Physical memory (GiB): 1007.2319526672363
# Number of CPU cores: 96
# CPU: x86_64

# %% [markdown]
# ## Insulin (Pilatus 6M, 100 frames)
#
# ### End-to-end tests
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_e2e.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_e2e-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2.import_data log', "mdx2.import_data"),
           ('mdx2.find_peaks log', "mdx2.find_peaks"),
           ('mdx2.mask_peaks log', "mdx2.mask_peaks"),
           ('mdx2.integrate log', "mdx2.integrate"),
           ('mdx2.scale log', "mdx2.scale"),
           ('mdx2.merge log', "mdx2.merge"),
           ('mdx2.reintegrate log', "mdx2.reintegrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# -------------------------------------Memory-------------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# -----------------------------------Wall time------------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# --------------------------------CPU percent est---------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.import_data log------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.find_peaks log-------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.mask_peaks log-------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# -------------------------------mdx2.integrate log-------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# ---------------------------------mdx2.scale log---------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# ---------------------------------mdx2.merge log---------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.reintegrate log------------------------------
# grep: ../runs/insulin_e2e-*/summary.log: No such file or directory

# %% [markdown]
# ### mdx2.integrate
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_integrate.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_integrate-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.integrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_integrate-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_integrate.sh --nproc 1
# ../runs/insulin_integrate-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_integrate.sh --nproc 2
# ../runs/insulin_integrate-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_integrate.sh --nproc 4
# ../runs/insulin_integrate-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_integrate.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_integrate-1/summary.log:peak_tree_rss_mib: 3688.82
# ../runs/insulin_integrate-1/summary.log:peak_seen_at:      2026-05-01 15:12:42
# ../runs/insulin_integrate-2/summary.log:peak_tree_rss_mib: 2458.91
# ../runs/insulin_integrate-2/summary.log:peak_seen_at:      2026-05-01 15:12:54
# ../runs/insulin_integrate-3/summary.log:peak_tree_rss_mib: 4178.09
# ../runs/insulin_integrate-3/summary.log:peak_seen_at:      2026-05-01 15:13:34
# ../runs/insulin_integrate-4/summary.log:peak_tree_rss_mib: 7971.81
# ../runs/insulin_integrate-4/summary.log:peak_seen_at:      2026-05-01 15:13:56
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_integrate-1/summary.log:Overall wall time: 00:01:15 (75s)
# ../runs/insulin_integrate-2/summary.log:Overall wall time: 00:00:40 (40s)
# ../runs/insulin_integrate-3/summary.log:Overall wall time: 00:00:22 (22s)
# ../runs/insulin_integrate-4/summary.log:Overall wall time: 00:00:15 (15s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_integrate-1/summary.log:cpu_pct_est:  99.5
# ../runs/insulin_integrate-2/summary.log:cpu_pct_est:  217.3
# ../runs/insulin_integrate-3/summary.log:cpu_pct_est:  414.4
# ../runs/insulin_integrate-4/summary.log:cpu_pct_est:  720.1
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_integrate-1/summary.log:2026-05-01 15:11:30.705	Starting mdx2.integrate at 2026-05-01 15:11:30
# ../runs/insulin_integrate-1/summary.log:2026-05-01 15:12:43.997	mdx2.integrate completed in 73.29 seconds
# ../runs/insulin_integrate-2/summary.log:2026-05-01 15:12:45.411	Starting mdx2.integrate at 2026-05-01 15:12:45
# ../runs/insulin_integrate-2/summary.log:2026-05-01 15:13:23.805	mdx2.integrate completed in 38.39 seconds
# ../runs/insulin_integrate-3/summary.log:2026-05-01 15:13:25.509	Starting mdx2.integrate at 2026-05-01 15:13:25
# ../runs/insulin_integrate-3/summary.log:2026-05-01 15:13:45.829	mdx2.integrate completed in 20.32 seconds
# ../runs/insulin_integrate-4/summary.log:2026-05-01 15:13:47.348	Starting mdx2.integrate at 2026-05-01 15:13:47
# ../runs/insulin_integrate-4/summary.log:2026-05-01 15:14:00.189	mdx2.integrate completed in 12.84 seconds

# %% [markdown]
# ### mdx2.import_data
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_import_data.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_import_data-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.import_data"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_import_data-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_import_data.sh --nproc 1
# ../runs/insulin_import_data-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_import_data.sh --nproc 2
# ../runs/insulin_import_data-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_import_data.sh --nproc 4
# ../runs/insulin_import_data-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_import_data.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_import_data-1/summary.log:peak_tree_rss_mib: 2702.63
# ../runs/insulin_import_data-1/summary.log:peak_seen_at:      2026-05-01 15:14:24
# ../runs/insulin_import_data-2/summary.log:peak_tree_rss_mib: 5626.00
# ../runs/insulin_import_data-2/summary.log:peak_seen_at:      2026-05-01 15:14:37
# ../runs/insulin_import_data-3/summary.log:peak_tree_rss_mib: 5718.53
# ../runs/insulin_import_data-3/summary.log:peak_seen_at:      2026-05-01 15:14:45
# ../runs/insulin_import_data-4/summary.log:peak_tree_rss_mib: 5910.14
# ../runs/insulin_import_data-4/summary.log:peak_seen_at:      2026-05-01 15:14:53
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_import_data-1/summary.log:Overall wall time: 00:00:15 (15s)
# ../runs/insulin_import_data-2/summary.log:Overall wall time: 00:00:10 (10s)
# ../runs/insulin_import_data-3/summary.log:Overall wall time: 00:00:09 (9s)
# ../runs/insulin_import_data-4/summary.log:Overall wall time: 00:00:10 (10s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_import_data-1/summary.log:cpu_pct_est:  99.4
# ../runs/insulin_import_data-2/summary.log:cpu_pct_est:  289.4
# ../runs/insulin_import_data-3/summary.log:cpu_pct_est:  290.8
# ../runs/insulin_import_data-4/summary.log:cpu_pct_est:  294.5
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_import_data-1/summary.log:2026-05-01 15:14:16.160	Starting mdx2.import_data at 2026-05-01 15:14:16
# ../runs/insulin_import_data-1/summary.log:2026-05-01 15:14:29.791	mdx2.import_data completed in 13.63 seconds
# ../runs/insulin_import_data-2/summary.log:2026-05-01 15:14:31.481	Starting mdx2.import_data at 2026-05-01 15:14:31
# ../runs/insulin_import_data-2/summary.log:2026-05-01 15:14:39.281	mdx2.import_data completed in 7.80 seconds
# ../runs/insulin_import_data-3/summary.log:2026-05-01 15:14:41.028	Starting mdx2.import_data at 2026-05-01 15:14:41
# ../runs/insulin_import_data-3/summary.log:2026-05-01 15:14:48.790	mdx2.import_data completed in 7.76 seconds
# ../runs/insulin_import_data-4/summary.log:2026-05-01 15:14:50.613	Starting mdx2.import_data at 2026-05-01 15:14:50
# ../runs/insulin_import_data-4/summary.log:2026-05-01 15:14:58.391	mdx2.import_data completed in 7.78 seconds

# %% [markdown]
# ### mdx2.find_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_find_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_find_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.find_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_find_peaks-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_find_peaks.sh --nproc 1
# ../runs/insulin_find_peaks-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_find_peaks.sh --nproc 2
# ../runs/insulin_find_peaks-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_find_peaks.sh --nproc 4
# ../runs/insulin_find_peaks-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_find_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_find_peaks-1/summary.log:peak_tree_rss_mib: 2569.26
# ../runs/insulin_find_peaks-1/summary.log:peak_seen_at:      2026-05-01 15:15:23
# ../runs/insulin_find_peaks-2/summary.log:peak_tree_rss_mib: 1689.87
# ../runs/insulin_find_peaks-2/summary.log:peak_seen_at:      2026-05-01 15:15:28
# ../runs/insulin_find_peaks-3/summary.log:peak_tree_rss_mib: 2409.01
# ../runs/insulin_find_peaks-3/summary.log:peak_seen_at:      2026-05-01 15:15:36
# ../runs/insulin_find_peaks-4/summary.log:peak_tree_rss_mib: 4243.12
# ../runs/insulin_find_peaks-4/summary.log:peak_seen_at:      2026-05-01 15:15:40
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_find_peaks-1/summary.log:Overall wall time: 00:00:10 (10s)
# ../runs/insulin_find_peaks-2/summary.log:Overall wall time: 00:00:07 (7s)
# ../runs/insulin_find_peaks-3/summary.log:Overall wall time: 00:00:06 (6s)
# ../runs/insulin_find_peaks-4/summary.log:Overall wall time: 00:00:04 (4s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_find_peaks-1/summary.log:cpu_pct_est:  99.4
# ../runs/insulin_find_peaks-2/summary.log:cpu_pct_est:  319.3
# ../runs/insulin_find_peaks-3/summary.log:cpu_pct_est:  493.2
# ../runs/insulin_find_peaks-4/summary.log:cpu_pct_est:  773.3
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_find_peaks-1/summary.log:2026-05-01 15:15:15.340	Starting mdx2.find_peaks at 2026-05-01 15:15:15
# ../runs/insulin_find_peaks-1/summary.log:2026-05-01 15:15:23.763	mdx2.find_peaks completed in 8.42 seconds
# ../runs/insulin_find_peaks-2/summary.log:2026-05-01 15:15:25.394	Starting mdx2.find_peaks at 2026-05-01 15:15:25
# ../runs/insulin_find_peaks-2/summary.log:2026-05-01 15:15:30.991	mdx2.find_peaks completed in 5.60 seconds
# ../runs/insulin_find_peaks-3/summary.log:2026-05-01 15:15:32.849	Starting mdx2.find_peaks at 2026-05-01 15:15:32
# ../runs/insulin_find_peaks-3/summary.log:2026-05-01 15:15:36.319	mdx2.find_peaks completed in 3.47 seconds
# ../runs/insulin_find_peaks-4/summary.log:2026-05-01 15:15:38.196	Starting mdx2.find_peaks at 2026-05-01 15:15:38
# ../runs/insulin_find_peaks-4/summary.log:2026-05-01 15:15:40.525	mdx2.find_peaks completed in 2.33 seconds

# %% [markdown]
# ### mdx2.mask_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_mask_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_mask_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.mask_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_mask_peaks.sh --nproc 1
# ../runs/insulin_mask_peaks-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_mask_peaks.sh --nproc 2
# ../runs/insulin_mask_peaks-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_mask_peaks.sh --nproc 4
# ../runs/insulin_mask_peaks-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/insulin_mask_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:peak_tree_rss_mib: 1450.39
# ../runs/insulin_mask_peaks-1/summary.log:peak_seen_at:      2026-05-01 15:44:20
# ../runs/insulin_mask_peaks-2/summary.log:peak_tree_rss_mib: 2630.10
# ../runs/insulin_mask_peaks-2/summary.log:peak_seen_at:      2026-05-01 15:44:43
# ../runs/insulin_mask_peaks-3/summary.log:peak_tree_rss_mib: 3757.57
# ../runs/insulin_mask_peaks-3/summary.log:peak_seen_at:      2026-05-01 15:44:59
# ../runs/insulin_mask_peaks-4/summary.log:peak_tree_rss_mib: 6112.73
# ../runs/insulin_mask_peaks-4/summary.log:peak_seen_at:      2026-05-01 15:45:13
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:Overall wall time: 00:00:47 (47s)
# ../runs/insulin_mask_peaks-2/summary.log:Overall wall time: 00:00:29 (29s)
# ../runs/insulin_mask_peaks-3/summary.log:Overall wall time: 00:00:18 (18s)
# ../runs/insulin_mask_peaks-4/summary.log:Overall wall time: 00:00:12 (12s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:cpu_pct_est:  99.5
# ../runs/insulin_mask_peaks-2/summary.log:cpu_pct_est:  2342.4
# ../runs/insulin_mask_peaks-3/summary.log:cpu_pct_est:  2077.6
# ../runs/insulin_mask_peaks-4/summary.log:cpu_pct_est:  1826.9
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:2026-05-01 15:43:34.449	Starting mdx2.mask_peaks at 2026-05-01 15:43:34
# ../runs/insulin_mask_peaks-1/summary.log:2026-05-01 15:44:20.471	mdx2.mask_peaks completed in 46.02 seconds
# ../runs/insulin_mask_peaks-2/summary.log:2026-05-01 15:44:21.764	Starting mdx2.mask_peaks at 2026-05-01 15:44:21
# ../runs/insulin_mask_peaks-2/summary.log:2026-05-01 15:44:49.024	mdx2.mask_peaks completed in 27.26 seconds
# ../runs/insulin_mask_peaks-3/summary.log:2026-05-01 15:44:50.578	Starting mdx2.mask_peaks at 2026-05-01 15:44:50
# ../runs/insulin_mask_peaks-3/summary.log:2026-05-01 15:45:06.459	mdx2.mask_peaks completed in 15.88 seconds
# ../runs/insulin_mask_peaks-4/summary.log:2026-05-01 15:45:08.164	Starting mdx2.mask_peaks at 2026-05-01 15:45:08
# ../runs/insulin_mask_peaks-4/summary.log:2026-05-01 15:45:18.573	mdx2.mask_peaks completed in 10.41 seconds

# %% [markdown]
# ### Peak memory comparison

# %%
import re
from pathlib import Path
import pandas as pd

def load_summary_data(*tests, base="../runs"):
    rows = []
    for test in tests:
        for log in Path(base).glob(f"{test}-*/summary.log"):
            txt = log.read_text(errors="ignore")

            nproc = re.search(r"--nproc\s+(\d+)", txt)
            mem = re.search(r"peak_tree_rss_mib:\s*([0-9.]+)", txt)

            # CPU profile summary lines from run_profile.sh
            real_s = re.search(r"(?m)^real_s:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)
            cpu_pct = re.search(r"(?m)^cpu_pct_est:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)

            if nproc and mem:
                rows.append({
                    "test": test,
                    "nproc": int(nproc.group(1)),
                    "peak_tree_rss_mib": float(mem.group(1)),
                    "real_s": float(real_s.group(1)) if real_s else None,
                    "cpu_pct_est": float(cpu_pct.group(1)) if cpu_pct else None,
                    "log": str(log),
                })

    if not rows:
        return pd.DataFrame(columns=[
            "test", "nproc", "peak_tree_rss_mib", "real_s", "cpu_pct_est", "log"
        ])

    return pd.DataFrame(rows).sort_values(["test", "nproc"])

df = load_summary_data("insulin_import_data",  "insulin_find_peaks", "insulin_mask_peaks", "insulin_integrate", "dev_insulin_integrate")
df.head()
# Out:
#                   test  nproc  peak_tree_rss_mib  real_s  cpu_pct_est  \
# 4   insulin_find_peaks      1            2569.26    9.59         99.4
# 5   insulin_find_peaks      2            1689.87    6.90        319.3
# 6   insulin_find_peaks      4            2409.01    4.97        493.2
# 7   insulin_find_peaks      8            4243.12    3.75        773.3
# 0  insulin_import_data      1            2702.63   14.86         99.4
#
#                                          log
# 4   ../runs/insulin_find_peaks-1/summary.log
# 5   ../runs/insulin_find_peaks-2/summary.log
# 6   ../runs/insulin_find_peaks-3/summary.log
# 7   ../runs/insulin_find_peaks-4/summary.log
# 0  ../runs/insulin_import_data-1/summary.log

# %%
ax = df.pivot_table(index="nproc", columns="test", values="peak_tree_rss_mib", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("peak_tree_rss (MiB)")
ax.set_title("Peak memory for insulin dataset (Pilatus 6M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="cpu_pct_est", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("CPU %")
ax.set_title("CPU usage for insulin dataset (Pilatus 6M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="real_s", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("Real time (s)")
ax.set_title("Real time for insulin dataset (Pilatus 6M, 100 frames)");
