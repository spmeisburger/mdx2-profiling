# %% [markdown]
# # mdx2 profiling summary

# %%
import os, platform, psutil

mem_bytes = psutil.virtual_memory().total
ncpu = os.cpu_count()
chip = platform.processor()  # or platform.machine()

print("Physical memory (GiB):", mem_bytes / 1024**3)
print("Number of CPU cores:", ncpu)
print("CPU:", chip)
# Out:
# Physical memory (GiB): 1007.2319526672363
# Number of CPU cores: 96
# CPU: x86_64

# %% [markdown]
# ## Mac1 (Eiger 16M, 100 frames)
#
# ### End-to-end tests
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_e2e.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_e2e-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2.import_data log', "mdx2.import_data"),
           ('mdx2.find_peaks log', "mdx2.find_peaks"),
           ('mdx2.mask_peaks log', "mdx2.mask_peaks"),
           ('mdx2.integrate log', "mdx2.integrate"),
           ('mdx2.scale log', "mdx2.scale"),
           ('mdx2.merge log', "mdx2.merge"),
           ('mdx2.reintegrate log', "mdx2.reintegrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# -------------------------------------Memory-------------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# -----------------------------------Wall time------------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# --------------------------------CPU percent est---------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.import_data log------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.find_peaks log-------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.mask_peaks log-------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# -------------------------------mdx2.integrate log-------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# ---------------------------------mdx2.scale log---------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# ---------------------------------mdx2.merge log---------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory
# ------------------------------mdx2.reintegrate log------------------------------
# grep: ../runs/mac1_e2e-*/summary.log: No such file or directory

# %% [markdown]
# ### mdx2.integrate
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_integrate.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_integrate-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.integrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_integrate-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_integrate.sh --nproc 1
# ../runs/mac1_integrate-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_integrate.sh --nproc 2
# ../runs/mac1_integrate-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_integrate.sh --nproc 4
# ../runs/mac1_integrate-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_integrate.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_integrate-1/summary.log:peak_tree_rss_mib: 12060.04
# ../runs/mac1_integrate-1/summary.log:peak_seen_at:      2026-05-01 15:34:33
# ../runs/mac1_integrate-2/summary.log:peak_tree_rss_mib: 7760.95
# ../runs/mac1_integrate-2/summary.log:peak_seen_at:      2026-05-01 15:35:09
# ../runs/mac1_integrate-3/summary.log:peak_tree_rss_mib: 14340.72
# ../runs/mac1_integrate-3/summary.log:peak_seen_at:      2026-05-01 15:37:03
# ../runs/mac1_integrate-4/summary.log:peak_tree_rss_mib: 25828.02
# ../runs/mac1_integrate-4/summary.log:peak_seen_at:      2026-05-01 15:38:07
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_integrate-1/summary.log:Overall wall time: 00:03:52 (232s)
# ../runs/mac1_integrate-2/summary.log:Overall wall time: 00:02:04 (124s)
# ../runs/mac1_integrate-3/summary.log:Overall wall time: 00:01:07 (67s)
# ../runs/mac1_integrate-4/summary.log:Overall wall time: 00:00:41 (41s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_integrate-1/summary.log:cpu_pct_est:  99.5
# ../runs/mac1_integrate-2/summary.log:cpu_pct_est:  203.4
# ../runs/mac1_integrate-3/summary.log:cpu_pct_est:  393.3
# ../runs/mac1_integrate-4/summary.log:cpu_pct_est:  740.1
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_integrate-1/summary.log:2026-05-01 15:30:51.792	Starting mdx2.integrate at 2026-05-01 15:30:51
# ../runs/mac1_integrate-1/summary.log:2026-05-01 15:34:41.894	mdx2.integrate completed in 230.10 seconds
# ../runs/mac1_integrate-2/summary.log:2026-05-01 15:34:43.079	Starting mdx2.integrate at 2026-05-01 15:34:43
# ../runs/mac1_integrate-2/summary.log:2026-05-01 15:36:45.808	mdx2.integrate completed in 122.73 seconds
# ../runs/mac1_integrate-3/summary.log:2026-05-01 15:36:47.741	Starting mdx2.integrate at 2026-05-01 15:36:47
# ../runs/mac1_integrate-3/summary.log:2026-05-01 15:37:53.019	mdx2.integrate completed in 65.28 seconds
# ../runs/mac1_integrate-4/summary.log:2026-05-01 15:37:54.614	Starting mdx2.integrate at 2026-05-01 15:37:54
# ../runs/mac1_integrate-4/summary.log:2026-05-01 15:38:33.390	mdx2.integrate completed in 38.78 seconds

# %% [markdown]
# ### mdx2.import_data
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_import_data.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_import_data-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.import_data"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_import_data-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_import_data.sh --nproc 1
# ../runs/mac1_import_data-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_import_data.sh --nproc 2
# ../runs/mac1_import_data-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_import_data.sh --nproc 4
# ../runs/mac1_import_data-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_import_data.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_import_data-1/summary.log:peak_tree_rss_mib: 7216.54
# ../runs/mac1_import_data-1/summary.log:peak_seen_at:      2026-05-01 15:35:49
# ../runs/mac1_import_data-2/summary.log:peak_tree_rss_mib: 13292.06
# ../runs/mac1_import_data-2/summary.log:peak_seen_at:      2026-05-01 15:36:30
# ../runs/mac1_import_data-3/summary.log:peak_tree_rss_mib: 11663.74
# ../runs/mac1_import_data-3/summary.log:peak_seen_at:      2026-05-01 15:36:52
# ../runs/mac1_import_data-4/summary.log:peak_tree_rss_mib: 11028.71
# ../runs/mac1_import_data-4/summary.log:peak_seen_at:      2026-05-01 15:37:13
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_import_data-1/summary.log:Overall wall time: 00:00:36 (36s)
# ../runs/mac1_import_data-2/summary.log:Overall wall time: 00:00:24 (24s)
# ../runs/mac1_import_data-3/summary.log:Overall wall time: 00:00:22 (22s)
# ../runs/mac1_import_data-4/summary.log:Overall wall time: 00:00:22 (22s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_import_data-1/summary.log:cpu_pct_est:  99.5
# ../runs/mac1_import_data-2/summary.log:cpu_pct_est:  229.0
# ../runs/mac1_import_data-3/summary.log:cpu_pct_est:  235.1
# ../runs/mac1_import_data-4/summary.log:cpu_pct_est:  229.3
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_import_data-1/summary.log:2026-05-01 15:35:42.165	Starting mdx2.import_data at 2026-05-01 15:35:42
# ../runs/mac1_import_data-1/summary.log:2026-05-01 15:36:17.113	mdx2.import_data completed in 34.95 seconds
# ../runs/mac1_import_data-2/summary.log:2026-05-01 15:36:18.584	Starting mdx2.import_data at 2026-05-01 15:36:18
# ../runs/mac1_import_data-2/summary.log:2026-05-01 15:36:41.363	mdx2.import_data completed in 22.78 seconds
# ../runs/mac1_import_data-3/summary.log:2026-05-01 15:36:42.903	Starting mdx2.import_data at 2026-05-01 15:36:42
# ../runs/mac1_import_data-3/summary.log:2026-05-01 15:37:02.308	mdx2.import_data completed in 19.41 seconds
# ../runs/mac1_import_data-4/summary.log:2026-05-01 15:37:04.431	Starting mdx2.import_data at 2026-05-01 15:37:04
# ../runs/mac1_import_data-4/summary.log:2026-05-01 15:37:24.851	mdx2.import_data completed in 20.42 seconds

# %% [markdown]
# ### mdx2.find_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_find_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_find_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.find_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_find_peaks-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_find_peaks.sh --nproc 1
# ../runs/mac1_find_peaks-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_find_peaks.sh --nproc 2
# ../runs/mac1_find_peaks-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_find_peaks.sh --nproc 4
# ../runs/mac1_find_peaks-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_find_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_find_peaks-1/summary.log:peak_tree_rss_mib: 7290.91
# ../runs/mac1_find_peaks-1/summary.log:peak_seen_at:      2026-05-01 15:34:17
# ../runs/mac1_find_peaks-2/summary.log:peak_tree_rss_mib: 1438.25
# ../runs/mac1_find_peaks-2/summary.log:peak_seen_at:      2026-05-01 15:34:22
# ../runs/mac1_find_peaks-3/summary.log:peak_tree_rss_mib: 2646.48
# ../runs/mac1_find_peaks-3/summary.log:peak_seen_at:      2026-05-01 15:34:39
# ../runs/mac1_find_peaks-4/summary.log:peak_tree_rss_mib: 4941.11
# ../runs/mac1_find_peaks-4/summary.log:peak_seen_at:      2026-05-01 15:34:45
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_find_peaks-1/summary.log:Overall wall time: 00:00:23 (23s)
# ../runs/mac1_find_peaks-2/summary.log:Overall wall time: 00:00:15 (15s)
# ../runs/mac1_find_peaks-3/summary.log:Overall wall time: 00:00:09 (9s)
# ../runs/mac1_find_peaks-4/summary.log:Overall wall time: 00:00:06 (6s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_find_peaks-1/summary.log:cpu_pct_est:  99.6
# ../runs/mac1_find_peaks-2/summary.log:cpu_pct_est:  255.6
# ../runs/mac1_find_peaks-3/summary.log:cpu_pct_est:  445.8
# ../runs/mac1_find_peaks-4/summary.log:cpu_pct_est:  724.1
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_find_peaks-1/summary.log:2026-05-01 15:33:55.981	Starting mdx2.find_peaks at 2026-05-01 15:33:55
# ../runs/mac1_find_peaks-1/summary.log:2026-05-01 15:34:18.370	mdx2.find_peaks completed in 22.39 seconds
# ../runs/mac1_find_peaks-2/summary.log:2026-05-01 15:34:19.749	Starting mdx2.find_peaks at 2026-05-01 15:34:19
# ../runs/mac1_find_peaks-2/summary.log:2026-05-01 15:34:32.663	mdx2.find_peaks completed in 12.91 seconds
# ../runs/mac1_find_peaks-3/summary.log:2026-05-01 15:34:34.153	Starting mdx2.find_peaks at 2026-05-01 15:34:34
# ../runs/mac1_find_peaks-3/summary.log:2026-05-01 15:34:41.507	mdx2.find_peaks completed in 7.35 seconds
# ../runs/mac1_find_peaks-4/summary.log:2026-05-01 15:34:43.161	Starting mdx2.find_peaks at 2026-05-01 15:34:43
# ../runs/mac1_find_peaks-4/summary.log:2026-05-01 15:34:47.752	mdx2.find_peaks completed in 4.59 seconds

# %% [markdown]
# ### mdx2.mask_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_mask_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_mask_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.mask_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_mask_peaks.sh --nproc 1
# ../runs/mac1_mask_peaks-2/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_mask_peaks.sh --nproc 2
# ../runs/mac1_mask_peaks-3/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_mask_peaks.sh --nproc 4
# ../runs/mac1_mask_peaks-4/summary.log:Command: bash /local/storage/steve/mdx2_dev/mdx2-profiling/mac1_mask_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:peak_tree_rss_mib: 5952.14
# ../runs/mac1_mask_peaks-1/summary.log:peak_seen_at:      2026-05-01 15:36:39
# ../runs/mac1_mask_peaks-2/summary.log:peak_tree_rss_mib: 9830.13
# ../runs/mac1_mask_peaks-2/summary.log:peak_seen_at:      2026-05-01 15:37:35
# ../runs/mac1_mask_peaks-3/summary.log:peak_tree_rss_mib: 15783.22
# ../runs/mac1_mask_peaks-3/summary.log:peak_seen_at:      2026-05-01 15:38:50
# ../runs/mac1_mask_peaks-4/summary.log:peak_tree_rss_mib: 29622.70
# ../runs/mac1_mask_peaks-4/summary.log:peak_seen_at:      2026-05-01 15:39:17
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:Overall wall time: 00:02:21 (141s)
# ../runs/mac1_mask_peaks-2/summary.log:Overall wall time: 00:01:23 (83s)
# ../runs/mac1_mask_peaks-3/summary.log:Overall wall time: 00:00:46 (46s)
# ../runs/mac1_mask_peaks-4/summary.log:Overall wall time: 00:00:31 (31s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:cpu_pct_est:  99.5
# ../runs/mac1_mask_peaks-2/summary.log:cpu_pct_est:  629.5
# ../runs/mac1_mask_peaks-3/summary.log:cpu_pct_est:  733.4
# ../runs/mac1_mask_peaks-4/summary.log:cpu_pct_est:  862.6
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:2026-05-01 15:34:41.923	Starting mdx2.mask_peaks at 2026-05-01 15:34:41
# ../runs/mac1_mask_peaks-1/summary.log:2026-05-01 15:37:01.942	mdx2.mask_peaks completed in 140.02 seconds
# ../runs/mac1_mask_peaks-2/summary.log:2026-05-01 15:37:03.769	Starting mdx2.mask_peaks at 2026-05-01 15:37:03
# ../runs/mac1_mask_peaks-2/summary.log:2026-05-01 15:38:24.183	mdx2.mask_peaks completed in 80.41 seconds
# ../runs/mac1_mask_peaks-3/summary.log:2026-05-01 15:38:26.174	Starting mdx2.mask_peaks at 2026-05-01 15:38:26
# ../runs/mac1_mask_peaks-3/summary.log:2026-05-01 15:39:10.139	mdx2.mask_peaks completed in 43.96 seconds
# ../runs/mac1_mask_peaks-4/summary.log:2026-05-01 15:39:12.126	Starting mdx2.mask_peaks at 2026-05-01 15:39:12
# ../runs/mac1_mask_peaks-4/summary.log:2026-05-01 15:39:41.727	mdx2.mask_peaks completed in 29.60 seconds

# %% [markdown]
# ### Peak memory comparison

# %%
import re
from pathlib import Path
import pandas as pd

def load_summary_data(*tests, base="../runs"):
    rows = []
    for test in tests:
        for log in Path(base).glob(f"{test}-*/summary.log"):
            txt = log.read_text(errors="ignore")

            nproc = re.search(r"--nproc\s+(\d+)", txt)
            mem = re.search(r"peak_tree_rss_mib:\s*([0-9.]+)", txt)

            # CPU profile summary lines from run_profile.sh
            real_s = re.search(r"(?m)^real_s:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)
            cpu_pct = re.search(r"(?m)^cpu_pct_est:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)

            if nproc and mem:
                rows.append({
                    "test": test,
                    "nproc": int(nproc.group(1)),
                    "peak_tree_rss_mib": float(mem.group(1)),
                    "real_s": float(real_s.group(1)) if real_s else None,
                    "cpu_pct_est": float(cpu_pct.group(1)) if cpu_pct else None,
                    "log": str(log),
                })

    if not rows:
        return pd.DataFrame(columns=[
            "test", "nproc", "peak_tree_rss_mib", "real_s", "cpu_pct_est", "log"
        ])

    return pd.DataFrame(rows).sort_values(["test", "nproc"])

df = load_summary_data("mac1_import_data",  "mac1_find_peaks", "mac1_mask_peaks", "mac1_integrate")
df.head()
# Out:
#                test  nproc  peak_tree_rss_mib  real_s  cpu_pct_est  \
# 4   mac1_find_peaks      1            7290.91   23.50         99.6
# 5   mac1_find_peaks      2            1438.25   14.21        255.6
# 6   mac1_find_peaks      4            2646.48    8.79        445.8
# 7   mac1_find_peaks      8            4941.11    6.22        724.1
# 0  mac1_import_data      1            7216.54   36.13         99.5
#
#                                       log
# 4   ../runs/mac1_find_peaks-1/summary.log
# 5   ../runs/mac1_find_peaks-2/summary.log
# 6   ../runs/mac1_find_peaks-3/summary.log
# 7   ../runs/mac1_find_peaks-4/summary.log
# 0  ../runs/mac1_import_data-1/summary.log

# %%
ax = df.pivot_table(index="nproc", columns="test", values="peak_tree_rss_mib", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("peak_tree_rss (MiB)")
ax.set_title("Peak memory for Mac1 dataset (Eiger 16M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="cpu_pct_est", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("CPU %")
ax.set_title("CPU usage for Mac1 dataset (Eiger 16M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="real_s", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("Real time (s)")
ax.set_title("Real time for Mac1 dataset (Eiger 16M, 100 frames)");
