# %% [markdown]
# # mdx2 profiling summary

# %%
import os, platform, psutil

mem_bytes = psutil.virtual_memory().total
ncpu = os.cpu_count()
chip = platform.processor()  # or platform.machine()

print("Physical memory (GiB):", mem_bytes / 1024**3)
print("Number of CPU cores:", ncpu)
print("CPU:", chip)
# Out:
# Physical memory (GiB): 24.0
# Number of CPU cores: 10
# CPU: Apple M4

# %% [markdown]
# ## Mac1 (Eiger 16M, 100 frames)
#
# ### End-to-end tests
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_e2e.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_e2e-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2.import_data log', "mdx2.import_data"),
           ('mdx2.find_peaks log', "mdx2.find_peaks"),
           ('mdx2.mask_peaks log', "mdx2.mask_peaks"),
           ('mdx2.integrate log', "mdx2.integrate"),
           ('mdx2.scale log', "mdx2.scale"),
           ('mdx2.merge log', "mdx2.merge"),
           ('mdx2.reintegrate log', "mdx2.reintegrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# -------------------------------------Memory-------------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# -----------------------------------Wall time------------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# --------------------------------CPU percent est---------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# ------------------------------mdx2.import_data log------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# ------------------------------mdx2.find_peaks log-------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# ------------------------------mdx2.mask_peaks log-------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# -------------------------------mdx2.integrate log-------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# ---------------------------------mdx2.scale log---------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# ---------------------------------mdx2.merge log---------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log
# ------------------------------mdx2.reintegrate log------------------------------
# zsh:1: no matches found: ../runs/mac1_e2e-*/summary.log

# %% [markdown]
# ### mdx2.integrate
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_integrate.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_integrate-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.integrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_integrate-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_integrate.sh --nproc 1
# ../runs/mac1_integrate-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_integrate.sh --nproc 2
# ../runs/mac1_integrate-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_integrate.sh --nproc 4
# ../runs/mac1_integrate-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_integrate.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_integrate-1/summary.log:peak_tree_rss_mib: 8398.39
# ../runs/mac1_integrate-1/summary.log:peak_seen_at:      2026-05-01 11:39:31
# ../runs/mac1_integrate-2/summary.log:peak_tree_rss_mib: 8406.36
# ../runs/mac1_integrate-2/summary.log:peak_seen_at:      2026-05-01 11:41:36
# ../runs/mac1_integrate-3/summary.log:peak_tree_rss_mib: 14338.44
# ../runs/mac1_integrate-3/summary.log:peak_seen_at:      2026-05-01 11:43:09
# ../runs/mac1_integrate-4/summary.log:peak_tree_rss_mib: 18540.58
# ../runs/mac1_integrate-4/summary.log:peak_seen_at:      2026-05-01 11:44:39
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_integrate-1/summary.log:Overall wall time: 00:03:03 (183s)
# ../runs/mac1_integrate-2/summary.log:Overall wall time: 00:01:55 (115s)
# ../runs/mac1_integrate-3/summary.log:Overall wall time: 00:01:21 (81s)
# ../runs/mac1_integrate-4/summary.log:Overall wall time: 00:01:45 (105s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_integrate-1/summary.log:cpu_pct_est:  99.8
# ../runs/mac1_integrate-2/summary.log:cpu_pct_est:  195.2
# ../runs/mac1_integrate-3/summary.log:cpu_pct_est:  377.2
# ../runs/mac1_integrate-4/summary.log:cpu_pct_est:  547.6
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_integrate-1/summary.log:2026-05-01 11:38:01.622	Starting mdx2.integrate at 2026-05-01 11:38:01
# ../runs/mac1_integrate-1/summary.log:2026-05-01 11:41:02.838	mdx2.integrate completed in 181.22 seconds
# ../runs/mac1_integrate-2/summary.log:2026-05-01 11:41:04.152	Starting mdx2.integrate at 2026-05-01 11:41:04
# ../runs/mac1_integrate-2/summary.log:2026-05-01 11:42:58.125	mdx2.integrate completed in 113.97 seconds
# ../runs/mac1_integrate-3/summary.log:2026-05-01 11:42:59.560	Starting mdx2.integrate at 2026-05-01 11:42:59
# ../runs/mac1_integrate-3/summary.log:2026-05-01 11:44:18.917	mdx2.integrate completed in 79.36 seconds
# ../runs/mac1_integrate-4/summary.log:2026-05-01 11:44:20.651	Starting mdx2.integrate at 2026-05-01 11:44:20
# ../runs/mac1_integrate-4/summary.log:2026-05-01 11:46:03.910	mdx2.integrate completed in 103.26 seconds

# %% [markdown]
# ### mdx2.import_data
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_import_data.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_import_data-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.import_data"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_import_data-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_import_data.sh --nproc 1
# ../runs/mac1_import_data-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_import_data.sh --nproc 2
# ../runs/mac1_import_data-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_import_data.sh --nproc 4
# ../runs/mac1_import_data-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_import_data.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_import_data-1/summary.log:peak_tree_rss_mib: 5006.91
# ../runs/mac1_import_data-1/summary.log:peak_seen_at:      2026-05-01 11:22:19
# ../runs/mac1_import_data-2/summary.log:peak_tree_rss_mib: 12996.19
# ../runs/mac1_import_data-2/summary.log:peak_seen_at:      2026-05-01 11:22:32
# ../runs/mac1_import_data-3/summary.log:peak_tree_rss_mib: 10311.20
# ../runs/mac1_import_data-3/summary.log:peak_seen_at:      2026-05-01 11:22:48
# ../runs/mac1_import_data-4/summary.log:peak_tree_rss_mib: 13062.86
# ../runs/mac1_import_data-4/summary.log:peak_seen_at:      2026-05-01 11:23:03
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_import_data-1/summary.log:Overall wall time: 00:00:25 (25s)
# ../runs/mac1_import_data-2/summary.log:Overall wall time: 00:00:15 (15s)
# ../runs/mac1_import_data-3/summary.log:Overall wall time: 00:00:16 (16s)
# ../runs/mac1_import_data-4/summary.log:Overall wall time: 00:00:15 (15s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_import_data-1/summary.log:cpu_pct_est:  98.5
# ../runs/mac1_import_data-2/summary.log:cpu_pct_est:  187.8
# ../runs/mac1_import_data-3/summary.log:cpu_pct_est:  189.1
# ../runs/mac1_import_data-4/summary.log:cpu_pct_est:  194.3
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_import_data-1/summary.log:2026-05-01 11:21:59.329	Starting mdx2.import_data at 2026-05-01 11:21:59
# ../runs/mac1_import_data-1/summary.log:2026-05-01 11:22:22.633	mdx2.import_data completed in 23.30 seconds
# ../runs/mac1_import_data-2/summary.log:2026-05-01 11:22:24.147	Starting mdx2.import_data at 2026-05-01 11:22:24
# ../runs/mac1_import_data-2/summary.log:2026-05-01 11:22:38.079	mdx2.import_data completed in 13.93 seconds
# ../runs/mac1_import_data-3/summary.log:2026-05-01 11:22:39.943	Starting mdx2.import_data at 2026-05-01 11:22:39
# ../runs/mac1_import_data-3/summary.log:2026-05-01 11:22:54.096	mdx2.import_data completed in 14.15 seconds
# ../runs/mac1_import_data-4/summary.log:2026-05-01 11:22:55.655	Starting mdx2.import_data at 2026-05-01 11:22:55
# ../runs/mac1_import_data-4/summary.log:2026-05-01 11:23:09.404	mdx2.import_data completed in 13.75 seconds

# %% [markdown]
# ### mdx2.find_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_find_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_find_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.find_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_find_peaks-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_find_peaks.sh --nproc 1
# ../runs/mac1_find_peaks-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_find_peaks.sh --nproc 2
# ../runs/mac1_find_peaks-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_find_peaks.sh --nproc 4
# ../runs/mac1_find_peaks-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_find_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_find_peaks-1/summary.log:peak_tree_rss_mib: 4679.36
# ../runs/mac1_find_peaks-1/summary.log:peak_seen_at:      2026-05-01 11:49:35
# ../runs/mac1_find_peaks-2/summary.log:peak_tree_rss_mib: 2116.19
# ../runs/mac1_find_peaks-2/summary.log:peak_seen_at:      2026-05-01 11:49:47
# ../runs/mac1_find_peaks-3/summary.log:peak_tree_rss_mib: 3689.67
# ../runs/mac1_find_peaks-3/summary.log:peak_seen_at:      2026-05-01 11:50:01
# ../runs/mac1_find_peaks-4/summary.log:peak_tree_rss_mib: 7160.53
# ../runs/mac1_find_peaks-4/summary.log:peak_seen_at:      2026-05-01 11:50:12
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_find_peaks-1/summary.log:Overall wall time: 00:00:18 (18s)
# ../runs/mac1_find_peaks-2/summary.log:Overall wall time: 00:00:19 (19s)
# ../runs/mac1_find_peaks-3/summary.log:Overall wall time: 00:00:13 (13s)
# ../runs/mac1_find_peaks-4/summary.log:Overall wall time: 00:00:10 (10s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_find_peaks-1/summary.log:cpu_pct_est:  97.5
# ../runs/mac1_find_peaks-2/summary.log:cpu_pct_est:  185.3
# ../runs/mac1_find_peaks-3/summary.log:cpu_pct_est:  338.2
# ../runs/mac1_find_peaks-4/summary.log:cpu_pct_est:  610.5
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_find_peaks-1/summary.log:2026-05-01 11:49:18.797	Starting mdx2.find_peaks at 2026-05-01 11:49:18
# ../runs/mac1_find_peaks-1/summary.log:2026-05-01 11:49:35.158	mdx2.find_peaks completed in 16.36 seconds
# ../runs/mac1_find_peaks-2/summary.log:2026-05-01 11:49:36.915	Starting mdx2.find_peaks at 2026-05-01 11:49:36
# ../runs/mac1_find_peaks-2/summary.log:2026-05-01 11:49:54.474	mdx2.find_peaks completed in 17.56 seconds
# ../runs/mac1_find_peaks-3/summary.log:2026-05-01 11:49:56.120	Starting mdx2.find_peaks at 2026-05-01 11:49:56
# ../runs/mac1_find_peaks-3/summary.log:2026-05-01 11:50:06.962	mdx2.find_peaks completed in 10.84 seconds
# ../runs/mac1_find_peaks-4/summary.log:2026-05-01 11:50:08.839	Starting mdx2.find_peaks at 2026-05-01 11:50:08
# ../runs/mac1_find_peaks-4/summary.log:2026-05-01 11:50:16.668	mdx2.find_peaks completed in 7.83 seconds

# %% [markdown]
# ### mdx2.mask_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh mac1_mask_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/mac1_mask_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.mask_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_mask_peaks.sh --nproc 1
# ../runs/mac1_mask_peaks-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_mask_peaks.sh --nproc 2
# ../runs/mac1_mask_peaks-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_mask_peaks.sh --nproc 4
# ../runs/mac1_mask_peaks-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/mac1_mask_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:peak_tree_rss_mib: 6161.09
# ../runs/mac1_mask_peaks-1/summary.log:peak_seen_at:      2026-05-01 11:25:10
# ../runs/mac1_mask_peaks-2/summary.log:peak_tree_rss_mib: 11672.59
# ../runs/mac1_mask_peaks-2/summary.log:peak_seen_at:      2026-05-01 11:26:29
# ../runs/mac1_mask_peaks-3/summary.log:peak_tree_rss_mib: 14001.94
# ../runs/mac1_mask_peaks-3/summary.log:peak_seen_at:      2026-05-01 11:27:11
# ../runs/mac1_mask_peaks-4/summary.log:peak_tree_rss_mib: 19062.84
# ../runs/mac1_mask_peaks-4/summary.log:peak_seen_at:      2026-05-01 11:28:30
# -----------------------------------Wall time------------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:Overall wall time: 00:01:31 (91s)
# ../runs/mac1_mask_peaks-2/summary.log:Overall wall time: 00:01:03 (63s)
# ../runs/mac1_mask_peaks-3/summary.log:Overall wall time: 00:00:57 (57s)
# ../runs/mac1_mask_peaks-4/summary.log:Overall wall time: 00:02:04 (124s)
# --------------------------------CPU percent est---------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:cpu_pct_est:  124.1
# ../runs/mac1_mask_peaks-2/summary.log:cpu_pct_est:  209.3
# ../runs/mac1_mask_peaks-3/summary.log:cpu_pct_est:  329.3
# ../runs/mac1_mask_peaks-4/summary.log:cpu_pct_est:  359.6
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/mac1_mask_peaks-1/summary.log:2026-05-01 11:24:08.477	Starting mdx2.mask_peaks at 2026-05-01 11:24:08
# ../runs/mac1_mask_peaks-1/summary.log:2026-05-01 11:25:38.863	mdx2.mask_peaks completed in 90.39 seconds
# ../runs/mac1_mask_peaks-2/summary.log:2026-05-01 11:25:40.059	Starting mdx2.mask_peaks at 2026-05-01 11:25:40
# ../runs/mac1_mask_peaks-2/summary.log:2026-05-01 11:26:40.833	mdx2.mask_peaks completed in 60.77 seconds
# ../runs/mac1_mask_peaks-3/summary.log:2026-05-01 11:26:42.559	Starting mdx2.mask_peaks at 2026-05-01 11:26:42
# ../runs/mac1_mask_peaks-3/summary.log:2026-05-01 11:27:38.559	mdx2.mask_peaks completed in 56.00 seconds
# ../runs/mac1_mask_peaks-4/summary.log:2026-05-01 11:27:40.047	Starting mdx2.mask_peaks at 2026-05-01 11:27:40
# ../runs/mac1_mask_peaks-4/summary.log:2026-05-01 11:29:41.070	mdx2.mask_peaks completed in 121.02 seconds

# %% [markdown]
# ### Peak memory comparison

# %%
import re
from pathlib import Path
import pandas as pd

def load_summary_data(*tests, base="../runs"):
    rows = []
    for test in tests:
        for log in Path(base).glob(f"{test}-*/summary.log"):
            txt = log.read_text(errors="ignore")

            nproc = re.search(r"--nproc\s+(\d+)", txt)
            mem = re.search(r"peak_tree_rss_mib:\s*([0-9.]+)", txt)

            # CPU profile summary lines from run_profile.sh
            real_s = re.search(r"(?m)^real_s:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)
            cpu_pct = re.search(r"(?m)^cpu_pct_est:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)

            if nproc and mem:
                rows.append({
                    "test": test,
                    "nproc": int(nproc.group(1)),
                    "peak_tree_rss_mib": float(mem.group(1)),
                    "real_s": float(real_s.group(1)) if real_s else None,
                    "cpu_pct_est": float(cpu_pct.group(1)) if cpu_pct else None,
                    "log": str(log),
                })

    if not rows:
        return pd.DataFrame(columns=[
            "test", "nproc", "peak_tree_rss_mib", "real_s", "cpu_pct_est", "log"
        ])

    return pd.DataFrame(rows).sort_values(["test", "nproc"])

df = load_summary_data("mac1_import_data",  "mac1_find_peaks", "mac1_mask_peaks", "mac1_integrate")
df.head()
# Out:
#                test  nproc  peak_tree_rss_mib  real_s  cpu_pct_est  \
# 7   mac1_find_peaks      1            4679.36   17.91         97.5
# 4   mac1_find_peaks      2            2116.19   19.03        185.3
# 6   mac1_find_peaks      4            3689.67   12.37        338.2
# 5   mac1_find_peaks      8            7160.53    9.35        610.5
# 0  mac1_import_data      1            5006.91   24.70         98.5
#
#                                       log
# 7   ../runs/mac1_find_peaks-1/summary.log
# 4   ../runs/mac1_find_peaks-2/summary.log
# 6   ../runs/mac1_find_peaks-3/summary.log
# 5   ../runs/mac1_find_peaks-4/summary.log
# 0  ../runs/mac1_import_data-1/summary.log

# %%
ax = df.pivot_table(index="nproc", columns="test", values="peak_tree_rss_mib", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("peak_tree_rss (MiB)")
ax.set_title("Peak memory for Mac1 dataset (Eiger 16M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="cpu_pct_est", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("CPU %")
ax.set_title("CPU usage for Mac1 dataset (Eiger 16M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="real_s", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("Real time (s)")
ax.set_title("Real time for Mac1 dataset (Eiger 16M, 100 frames)");
