# %% [markdown]
# # mdx2 profiling summary

# %%
memsize = !sysctl -n hw.memsize
ncpu = !sysctl -n hw.ncpu
chip = !sysctl -n machdep.cpu.brand_string 2>/dev/null || system_profiler SPHardwareDataType | grep "Chip"
mem_bytes = int(memsize[0])
print("Physical memory (GiB):", int(memsize[0]) / 1024**3)
print("Number of CPU cores:", int(ncpu[0]))
print("CPU:", chip[0])
# Out:
# Physical memory (GiB): 24.0
# Number of CPU cores: 10
# CPU: Apple M4

# %% [markdown]
# ## Insulin (Pilatus 6M, 100 frames)
#
# ### End-to-end tests
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_e2e.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_e2e-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2.import_data log', "mdx2.import_data"),
           ('mdx2.find_peaks log', "mdx2.find_peaks"),
           ('mdx2.mask_peaks log', "mdx2.mask_peaks"),
           ('mdx2.integrate log', "mdx2.integrate"),
           ('mdx2.scale log', "mdx2.scale"),
           ('mdx2.merge log', "mdx2.merge"),
           ('mdx2.reintegrate log', "mdx2.reintegrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_e2e-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_e2e.sh --nproc 1
# ../runs/insulin_e2e-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_e2e.sh --nproc 2
# ../runs/insulin_e2e-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_e2e.sh --nproc 4
# ../runs/insulin_e2e-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_e2e.sh --nproc 8
# ../runs/insulin_e2e-5/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_e2e.sh --nproc 4
# ../runs/insulin_e2e-6/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_e2e.sh --nproc 4
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_e2e-1/summary.log:peak_tree_rss_mib: 2925.38
# ../runs/insulin_e2e-1/summary.log:peak_seen_at:      2026-05-01 10:09:48
# ../runs/insulin_e2e-2/summary.log:peak_tree_rss_mib: 4186.45
# ../runs/insulin_e2e-2/summary.log:peak_seen_at:      2026-05-01 10:11:44
# ../runs/insulin_e2e-3/summary.log:peak_tree_rss_mib: 6325.36
# ../runs/insulin_e2e-3/summary.log:peak_seen_at:      2026-05-01 10:14:28
# ../runs/insulin_e2e-4/summary.log:peak_tree_rss_mib: 9922.59
# ../runs/insulin_e2e-4/summary.log:peak_seen_at:      2026-05-01 10:16:28
# ../runs/insulin_e2e-5/summary.log:peak_tree_rss_mib: 1.48
# ../runs/insulin_e2e-5/summary.log:peak_seen_at:      2026-05-01 13:59:16
# ../runs/insulin_e2e-6/summary.log:peak_tree_rss_mib: 2101.80
# ../runs/insulin_e2e-6/summary.log:peak_seen_at:      2026-05-01 14:02:51
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_e2e-1/summary.log:Overall wall time: 00:03:12 (192s)
# ../runs/insulin_e2e-2/summary.log:Overall wall time: 00:02:20 (140s)
# ../runs/insulin_e2e-3/summary.log:Overall wall time: 00:01:53 (113s)
# ../runs/insulin_e2e-4/summary.log:Overall wall time: 00:01:59 (119s)
# ../runs/insulin_e2e-5/summary.log:Overall wall time: 00:00:01 (1s)
# ../runs/insulin_e2e-6/summary.log:Overall wall time: 00:00:19 (19s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_e2e-1/summary.log:cpu_pct_est:  105.7
# ../runs/insulin_e2e-2/summary.log:cpu_pct_est:  178.9
# ../runs/insulin_e2e-3/summary.log:cpu_pct_est:  290.3
# ../runs/insulin_e2e-4/summary.log:cpu_pct_est:  494.4
# ../runs/insulin_e2e-5/summary.log:cpu_pct_est:  0.0
# ../runs/insulin_e2e-6/summary.log:cpu_pct_est:  167.2
# ------------------------------mdx2.import_data log------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:25.033	Starting mdx2.import_data at 2026-05-01 10:08:25
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:25.864	mdx2.import_data completed in 0.83 seconds
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:29.592	Starting mdx2.import_data at 2026-05-01 10:08:29
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:37.489	mdx2.import_data completed in 7.90 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:33.126	Starting mdx2.import_data at 2026-05-01 10:11:33
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:34.645	mdx2.import_data completed in 1.52 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:39.145	Starting mdx2.import_data at 2026-05-01 10:11:39
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:44.459	mdx2.import_data completed in 5.31 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:13:51.384	Starting mdx2.import_data at 2026-05-01 10:13:51
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:13:53.019	mdx2.import_data completed in 1.64 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:13:57.614	Starting mdx2.import_data at 2026-05-01 10:13:57
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:02.999	mdx2.import_data completed in 5.38 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:15:45.220	Starting mdx2.import_data at 2026-05-01 10:15:45
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:15:46.847	mdx2.import_data completed in 1.63 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:15:51.829	Starting mdx2.import_data at 2026-05-01 10:15:51
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:15:57.316	mdx2.import_data completed in 5.49 seconds
# ../runs/insulin_e2e-6/summary.log:2026-05-01 14:02:59.353	Starting mdx2.import_data at 2026-05-01 14:02:59
# ../runs/insulin_e2e-6/summary.log:2026-05-01 14:03:01.635	mdx2.import_data completed in 2.28 seconds
# ------------------------------mdx2.find_peaks log-------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:40.015	Starting mdx2.find_peaks at 2026-05-01 10:08:40
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:46.361	mdx2.find_peaks completed in 6.35 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:47.099	Starting mdx2.find_peaks at 2026-05-01 10:11:47
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:52.858	mdx2.find_peaks completed in 5.76 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:05.655	Starting mdx2.find_peaks at 2026-05-01 10:14:05
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:10.557	mdx2.find_peaks completed in 4.90 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:00.039	Starting mdx2.find_peaks at 2026-05-01 10:16:00
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:03.261	mdx2.find_peaks completed in 3.22 seconds
# ------------------------------mdx2.mask_peaks log-------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:08:47.503	Starting mdx2.mask_peaks at 2026-05-01 10:08:47
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:09:12.701	mdx2.mask_peaks completed in 25.20 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:11:54.079	Starting mdx2.mask_peaks at 2026-05-01 10:11:54
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:12:14.074	mdx2.mask_peaks completed in 19.99 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:11.879	Starting mdx2.mask_peaks at 2026-05-01 10:14:11
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:28.123	mdx2.mask_peaks completed in 16.24 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:04.622	Starting mdx2.mask_peaks at 2026-05-01 10:16:04
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:21.800	mdx2.mask_peaks completed in 17.18 seconds
# -------------------------------mdx2.integrate log-------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:09:13.857	Starting mdx2.integrate at 2026-05-01 10:09:13
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:10:07.297	mdx2.integrate completed in 53.44 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:12:15.396	Starting mdx2.integrate at 2026-05-01 10:12:15
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:12:48.598	mdx2.integrate completed in 33.20 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:29.548	Starting mdx2.integrate at 2026-05-01 10:14:29
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:52.813	mdx2.integrate completed in 23.27 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:23.363	Starting mdx2.integrate at 2026-05-01 10:16:23
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:44.827	mdx2.integrate completed in 21.46 seconds
# ---------------------------------mdx2.scale log---------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:10:10.201	Starting mdx2.scale at 2026-05-01 10:10:10
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:10:18.771	mdx2.scale completed in 8.57 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:12:51.550	Starting mdx2.scale at 2026-05-01 10:12:51
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:13:00.080	mdx2.scale completed in 8.53 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:14:55.976	Starting mdx2.scale at 2026-05-01 10:14:55
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:15:04.646	mdx2.scale completed in 8.67 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:48.278	Starting mdx2.scale at 2026-05-01 10:16:48
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:56.855	mdx2.scale completed in 8.58 seconds
# ---------------------------------mdx2.merge log---------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:10:19.957	Starting mdx2.merge at 2026-05-01 10:10:19
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:10:20.366	mdx2.merge completed in 0.41 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:13:01.277	Starting mdx2.merge at 2026-05-01 10:13:01
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:13:01.685	mdx2.merge completed in 0.41 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:15:05.896	Starting mdx2.merge at 2026-05-01 10:15:05
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:15:06.309	mdx2.merge completed in 0.41 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:58.044	Starting mdx2.merge at 2026-05-01 10:16:58
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:58.449	mdx2.merge completed in 0.41 seconds
# ------------------------------mdx2.reintegrate log------------------------------
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:10:21.538	Starting mdx2.reintegrate at 2026-05-01 10:10:21
# ../runs/insulin_e2e-1/summary.log:2026-05-01 10:11:17.692	mdx2.reintegrate completed in 56.15 seconds
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:13:02.835	Starting mdx2.reintegrate at 2026-05-01 10:13:02
# ../runs/insulin_e2e-2/summary.log:2026-05-01 10:13:37.661	mdx2.reintegrate completed in 34.83 seconds
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:15:07.473	Starting mdx2.reintegrate at 2026-05-01 10:15:07
# ../runs/insulin_e2e-3/summary.log:2026-05-01 10:15:31.262	mdx2.reintegrate completed in 23.79 seconds
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:16:59.606	Starting mdx2.reintegrate at 2026-05-01 10:16:59
# ../runs/insulin_e2e-4/summary.log:2026-05-01 10:17:29.310	mdx2.reintegrate completed in 29.70 seconds

# %% [markdown]
# ### mdx2.integrate
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_integrate.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_integrate-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.integrate"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_integrate-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_integrate.sh --nproc 1
# ../runs/insulin_integrate-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_integrate.sh --nproc 2
# ../runs/insulin_integrate-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_integrate.sh --nproc 4
# ../runs/insulin_integrate-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_integrate.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_integrate-1/summary.log:peak_tree_rss_mib: 2948.92
# ../runs/insulin_integrate-1/summary.log:peak_seen_at:      2026-05-01 09:57:10
# ../runs/insulin_integrate-2/summary.log:peak_tree_rss_mib: 3224.78
# ../runs/insulin_integrate-2/summary.log:peak_seen_at:      2026-05-01 09:57:54
# ../runs/insulin_integrate-3/summary.log:peak_tree_rss_mib: 5990.44
# ../runs/insulin_integrate-3/summary.log:peak_seen_at:      2026-05-01 09:58:25
# ../runs/insulin_integrate-4/summary.log:peak_tree_rss_mib: 8065.66
# ../runs/insulin_integrate-4/summary.log:peak_seen_at:      2026-05-01 09:58:49
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_integrate-1/summary.log:Overall wall time: 00:00:55 (55s)
# ../runs/insulin_integrate-2/summary.log:Overall wall time: 00:00:35 (35s)
# ../runs/insulin_integrate-3/summary.log:Overall wall time: 00:00:25 (25s)
# ../runs/insulin_integrate-4/summary.log:Overall wall time: 00:00:22 (22s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_integrate-1/summary.log:cpu_pct_est:  99.8
# ../runs/insulin_integrate-2/summary.log:cpu_pct_est:  194.3
# ../runs/insulin_integrate-3/summary.log:cpu_pct_est:  372.0
# ../runs/insulin_integrate-4/summary.log:cpu_pct_est:  681.4
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_integrate-1/summary.log:2026-05-01 09:56:37.603	Starting mdx2.integrate at 2026-05-01 09:56:37
# ../runs/insulin_integrate-1/summary.log:2026-05-01 09:57:31.262	mdx2.integrate completed in 53.66 seconds
# ../runs/insulin_integrate-2/summary.log:2026-05-01 09:57:32.849	Starting mdx2.integrate at 2026-05-01 09:57:32
# ../runs/insulin_integrate-2/summary.log:2026-05-01 09:58:06.146	mdx2.integrate completed in 33.30 seconds
# ../runs/insulin_integrate-3/summary.log:2026-05-01 09:58:07.861	Starting mdx2.integrate at 2026-05-01 09:58:07
# ../runs/insulin_integrate-3/summary.log:2026-05-01 09:58:30.539	mdx2.integrate completed in 22.68 seconds
# ../runs/insulin_integrate-4/summary.log:2026-05-01 09:58:32.322	Starting mdx2.integrate at 2026-05-01 09:58:32
# ../runs/insulin_integrate-4/summary.log:2026-05-01 09:58:52.743	mdx2.integrate completed in 20.42 seconds

# %% [markdown]
# ### mdx2.import_data
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_import_data.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_import_data-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.import_data"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_import_data-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_import_data.sh --nproc 1
# ../runs/insulin_import_data-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_import_data.sh --nproc 2
# ../runs/insulin_import_data-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_import_data.sh --nproc 4
# ../runs/insulin_import_data-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_import_data.sh --nproc 8
# ../runs/insulin_import_data-5/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_import_data.sh --nproc 4
# ../runs/insulin_import_data-6/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_import_data.sh --nproc 4
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_import_data-1/summary.log:peak_tree_rss_mib: 1973.41
# ../runs/insulin_import_data-1/summary.log:peak_seen_at:      2026-05-01 10:02:07
# ../runs/insulin_import_data-2/summary.log:peak_tree_rss_mib: 4238.81
# ../runs/insulin_import_data-2/summary.log:peak_seen_at:      2026-05-01 10:02:14
# ../runs/insulin_import_data-3/summary.log:peak_tree_rss_mib: 5396.39
# ../runs/insulin_import_data-3/summary.log:peak_seen_at:      2026-05-01 10:02:20
# ../runs/insulin_import_data-4/summary.log:peak_tree_rss_mib: 4471.27
# ../runs/insulin_import_data-4/summary.log:peak_seen_at:      2026-05-01 10:02:28
# ../runs/insulin_import_data-5/summary.log:peak_tree_rss_mib: 1.27
# ../runs/insulin_import_data-5/summary.log:peak_seen_at:      2026-05-01 13:59:01
# ../runs/insulin_import_data-6/summary.log:peak_tree_rss_mib: 5099.45
# ../runs/insulin_import_data-6/summary.log:peak_seen_at:      2026-05-01 14:01:39
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_import_data-1/summary.log:Overall wall time: 00:00:10 (10s)
# ../runs/insulin_import_data-2/summary.log:Overall wall time: 00:00:07 (7s)
# ../runs/insulin_import_data-3/summary.log:Overall wall time: 00:00:06 (6s)
# ../runs/insulin_import_data-4/summary.log:Overall wall time: 00:00:08 (8s)
# ../runs/insulin_import_data-5/summary.log:Overall wall time: 00:00:01 (1s)
# ../runs/insulin_import_data-6/summary.log:Overall wall time: 00:00:08 (8s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_import_data-1/summary.log:cpu_pct_est:  94.8
# ../runs/insulin_import_data-2/summary.log:cpu_pct_est:  178.1
# ../runs/insulin_import_data-3/summary.log:cpu_pct_est:  184.2
# ../runs/insulin_import_data-4/summary.log:cpu_pct_est:  193.5
# ../runs/insulin_import_data-5/summary.log:cpu_pct_est:  0.0
# ../runs/insulin_import_data-6/summary.log:cpu_pct_est:  162.0
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_import_data-1/summary.log:2026-05-01 10:02:01.686	Starting mdx2.import_data at 2026-05-01 10:02:01
# ../runs/insulin_import_data-1/summary.log:2026-05-01 10:02:09.953	mdx2.import_data completed in 8.27 seconds
# ../runs/insulin_import_data-2/summary.log:2026-05-01 10:02:11.379	Starting mdx2.import_data at 2026-05-01 10:02:11
# ../runs/insulin_import_data-2/summary.log:2026-05-01 10:02:16.887	mdx2.import_data completed in 5.51 seconds
# ../runs/insulin_import_data-3/summary.log:2026-05-01 10:02:18.187	Starting mdx2.import_data at 2026-05-01 10:02:18
# ../runs/insulin_import_data-3/summary.log:2026-05-01 10:02:23.579	mdx2.import_data completed in 5.39 seconds
# ../runs/insulin_import_data-4/summary.log:2026-05-01 10:02:25.001	Starting mdx2.import_data at 2026-05-01 10:02:25
# ../runs/insulin_import_data-4/summary.log:2026-05-01 10:02:30.479	mdx2.import_data completed in 5.48 seconds
# ../runs/insulin_import_data-6/summary.log:2026-05-01 14:01:34.632	Starting mdx2.import_data at 2026-05-01 14:01:34
# ../runs/insulin_import_data-6/summary.log:2026-05-01 14:01:40.005	mdx2.import_data completed in 5.37 seconds

# %% [markdown]
# ### mdx2.find_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_find_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_find_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.find_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_find_peaks-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_find_peaks.sh --nproc 1
# ../runs/insulin_find_peaks-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_find_peaks.sh --nproc 2
# ../runs/insulin_find_peaks-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_find_peaks.sh --nproc 4
# ../runs/insulin_find_peaks-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_find_peaks.sh --nproc 8
# ../runs/insulin_find_peaks-5/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_find_peaks.sh --nproc 4
# ../runs/insulin_find_peaks-6/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_find_peaks.sh --nproc 4
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_find_peaks-1/summary.log:peak_tree_rss_mib: 2044.81
# ../runs/insulin_find_peaks-1/summary.log:peak_seen_at:      2026-05-01 11:50:33
# ../runs/insulin_find_peaks-2/summary.log:peak_tree_rss_mib: 1550.77
# ../runs/insulin_find_peaks-2/summary.log:peak_seen_at:      2026-05-01 11:50:41
# ../runs/insulin_find_peaks-3/summary.log:peak_tree_rss_mib: 2653.92
# ../runs/insulin_find_peaks-3/summary.log:peak_seen_at:      2026-05-01 11:50:46
# ../runs/insulin_find_peaks-4/summary.log:peak_tree_rss_mib: 4722.83
# ../runs/insulin_find_peaks-4/summary.log:peak_seen_at:      2026-05-01 11:50:53
# ../runs/insulin_find_peaks-5/summary.log:peak_tree_rss_mib: 1.80
# ../runs/insulin_find_peaks-5/summary.log:peak_seen_at:      2026-05-01 13:59:12
# ../runs/insulin_find_peaks-6/summary.log:peak_tree_rss_mib: 2780.95
# ../runs/insulin_find_peaks-6/summary.log:peak_seen_at:      2026-05-01 14:02:29
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_find_peaks-1/summary.log:Overall wall time: 00:00:08 (8s)
# ../runs/insulin_find_peaks-2/summary.log:Overall wall time: 00:00:08 (8s)
# ../runs/insulin_find_peaks-3/summary.log:Overall wall time: 00:00:06 (6s)
# ../runs/insulin_find_peaks-4/summary.log:Overall wall time: 00:00:05 (5s)
# ../runs/insulin_find_peaks-5/summary.log:Overall wall time: 00:00:01 (1s)
# ../runs/insulin_find_peaks-6/summary.log:Overall wall time: 00:00:49 (49s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_find_peaks-1/summary.log:cpu_pct_est:  98.1
# ../runs/insulin_find_peaks-2/summary.log:cpu_pct_est:  176.0
# ../runs/insulin_find_peaks-3/summary.log:cpu_pct_est:  316.2
# ../runs/insulin_find_peaks-4/summary.log:cpu_pct_est:  562.4
# ../runs/insulin_find_peaks-5/summary.log:cpu_pct_est:  0.0
# ../runs/insulin_find_peaks-6/summary.log:cpu_pct_est:  383.3
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_find_peaks-1/summary.log:2026-05-01 11:50:27.817	Starting mdx2.find_peaks at 2026-05-01 11:50:27
# ../runs/insulin_find_peaks-1/summary.log:2026-05-01 11:50:34.388	mdx2.find_peaks completed in 6.57 seconds
# ../runs/insulin_find_peaks-2/summary.log:2026-05-01 11:50:35.632	Starting mdx2.find_peaks at 2026-05-01 11:50:35
# ../runs/insulin_find_peaks-2/summary.log:2026-05-01 11:50:41.742	mdx2.find_peaks completed in 6.11 seconds
# ../runs/insulin_find_peaks-3/summary.log:2026-05-01 11:50:43.493	Starting mdx2.find_peaks at 2026-05-01 11:50:43
# ../runs/insulin_find_peaks-3/summary.log:2026-05-01 11:50:48.394	mdx2.find_peaks completed in 4.90 seconds
# ../runs/insulin_find_peaks-4/summary.log:2026-05-01 11:50:49.885	Starting mdx2.find_peaks at 2026-05-01 11:50:49
# ../runs/insulin_find_peaks-4/summary.log:2026-05-01 11:50:53.144	mdx2.find_peaks completed in 3.26 seconds
# ../runs/insulin_find_peaks-6/summary.log:2026-05-01 14:01:49.439	Starting mdx2.find_peaks at 2026-05-01 14:01:49
# ../runs/insulin_find_peaks-6/summary.log:2026-05-01 14:02:36.685	mdx2.find_peaks completed in 47.25 seconds

# %% [markdown]
# ### mdx2.mask_peaks
#
# ```bash
# for n in 1 2 4 8; do ./run_profile.sh insulin_mask_peaks.sh --nproc "$n"; done
# ```

# %%
summary_files = "../runs/insulin_mask_peaks-*/summary.log"

matches = (('Command line', "Command:"),
           ('Memory', "peak_tree_rss|peak_seen_at"),
           ('Wall time', "Overall wall time"),
           ('CPU percent est', "cpu_pct_est:"),
           ('mdx2 Logs', "mdx2.mask_peaks"))

for title, pattern in matches:
    # print the title (80 char width, centered)
    print(title.center(80, '-'))
    # !grep -E "$pattern" $summary_files
# Out:
# ----------------------------------Command line----------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_mask_peaks.sh --nproc 1
# ../runs/insulin_mask_peaks-2/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_mask_peaks.sh --nproc 2
# ../runs/insulin_mask_peaks-3/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_mask_peaks.sh --nproc 4
# ../runs/insulin_mask_peaks-4/summary.log:Command: bash /Users/steve/dev/mdx2_tests/regression_tests/insulin_mask_peaks.sh --nproc 8
# -------------------------------------Memory-------------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:peak_tree_rss_mib: 2360.20
# ../runs/insulin_mask_peaks-1/summary.log:peak_seen_at:      2026-05-01 10:18:32
# ../runs/insulin_mask_peaks-2/summary.log:peak_tree_rss_mib: 3953.80
# ../runs/insulin_mask_peaks-2/summary.log:peak_seen_at:      2026-05-01 10:18:55
# ../runs/insulin_mask_peaks-3/summary.log:peak_tree_rss_mib: 6332.53
# ../runs/insulin_mask_peaks-3/summary.log:peak_seen_at:      2026-05-01 10:19:13
# ../runs/insulin_mask_peaks-4/summary.log:peak_tree_rss_mib: 9195.97
# ../runs/insulin_mask_peaks-4/summary.log:peak_seen_at:      2026-05-01 10:19:27
# -----------------------------------Wall time------------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:Overall wall time: 00:00:28 (28s)
# ../runs/insulin_mask_peaks-2/summary.log:Overall wall time: 00:00:22 (22s)
# ../runs/insulin_mask_peaks-3/summary.log:Overall wall time: 00:00:18 (18s)
# ../runs/insulin_mask_peaks-4/summary.log:Overall wall time: 00:00:18 (18s)
# --------------------------------CPU percent est---------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:cpu_pct_est:  130.3
# ../runs/insulin_mask_peaks-2/summary.log:cpu_pct_est:  210.6
# ../runs/insulin_mask_peaks-3/summary.log:cpu_pct_est:  355.7
# ../runs/insulin_mask_peaks-4/summary.log:cpu_pct_est:  624.8
# -----------------------------------mdx2 Logs------------------------------------
# ../runs/insulin_mask_peaks-1/summary.log:2026-05-01 10:18:06.909	Starting mdx2.mask_peaks at 2026-05-01 10:18:06
# ../runs/insulin_mask_peaks-1/summary.log:2026-05-01 10:18:33.261	mdx2.mask_peaks completed in 26.35 seconds
# ../runs/insulin_mask_peaks-2/summary.log:2026-05-01 10:18:34.984	Starting mdx2.mask_peaks at 2026-05-01 10:18:34
# ../runs/insulin_mask_peaks-2/summary.log:2026-05-01 10:18:55.579	mdx2.mask_peaks completed in 20.59 seconds
# ../runs/insulin_mask_peaks-3/summary.log:2026-05-01 10:18:57.095	Starting mdx2.mask_peaks at 2026-05-01 10:18:57
# ../runs/insulin_mask_peaks-3/summary.log:2026-05-01 10:19:13.474	mdx2.mask_peaks completed in 16.38 seconds
# ../runs/insulin_mask_peaks-4/summary.log:2026-05-01 10:19:15.242	Starting mdx2.mask_peaks at 2026-05-01 10:19:15
# ../runs/insulin_mask_peaks-4/summary.log:2026-05-01 10:19:31.771	mdx2.mask_peaks completed in 16.53 seconds

# %% [markdown]
# ### Peak memory comparison

# %%
import re
from pathlib import Path
import pandas as pd

def load_summary_data(*tests, base="../runs"):
    rows = []
    for test in tests:
        for log in Path(base).glob(f"{test}-*/summary.log"):
            txt = log.read_text(errors="ignore")

            nproc = re.search(r"--nproc\s+(\d+)", txt)
            mem = re.search(r"peak_tree_rss_mib:\s*([0-9.]+)", txt)

            # CPU profile summary lines from run_profile.sh
            real_s = re.search(r"(?m)^real_s:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)
            cpu_pct = re.search(r"(?m)^cpu_pct_est:\s*([0-9]+(?:\.[0-9]+)?)\s*$", txt)

            if nproc and mem:
                rows.append({
                    "test": test,
                    "nproc": int(nproc.group(1)),
                    "peak_tree_rss_mib": float(mem.group(1)),
                    "real_s": float(real_s.group(1)) if real_s else None,
                    "cpu_pct_est": float(cpu_pct.group(1)) if cpu_pct else None,
                    "log": str(log),
                })

    if not rows:
        return pd.DataFrame(columns=[
            "test", "nproc", "peak_tree_rss_mib", "real_s", "cpu_pct_est", "log"
        ])

    return pd.DataFrame(rows).sort_values(["test", "nproc"])

df = load_summary_data("insulin_import_data",  "insulin_find_peaks", "insulin_mask_peaks", "insulin_integrate", "dev_insulin_integrate")
df.head()
# Out:
#                      test  nproc  peak_tree_rss_mib  real_s  cpu_pct_est  \
# 23  dev_insulin_integrate      1            3415.44   49.60         99.8
# 22  dev_insulin_integrate      2            3407.14   31.34        191.4
# 20  dev_insulin_integrate      4            6380.77   20.99        366.5
# 21  dev_insulin_integrate      8           12601.42   17.38        701.3
# 10     insulin_find_peaks      1            2044.81    7.80         98.1
#
#                                             log
# 23  ../runs/dev_insulin_integrate-1/summary.log
# 22  ../runs/dev_insulin_integrate-2/summary.log
# 20  ../runs/dev_insulin_integrate-3/summary.log
# 21  ../runs/dev_insulin_integrate-4/summary.log
# 10     ../runs/insulin_find_peaks-1/summary.log

# %%
ax = df.pivot_table(index="nproc", columns="test", values="peak_tree_rss_mib", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("peak_tree_rss (MiB)")
ax.set_title("Peak memory for insulin dataset (Pilatus 6M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="cpu_pct_est", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("CPU %")
ax.set_title("CPU usage for insulin dataset (Pilatus 6M, 100 frames)");

# %%
ax = df.pivot_table(index="nproc", columns="test", values="real_s", aggfunc="mean").plot(marker="o")
ax.set_xlabel("nproc")
ax.set_ylabel("Real time (s)")
ax.set_title("Real time for insulin dataset (Pilatus 6M, 100 frames)");
